# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
import json
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
uk_food_db=mongo['uk_food']

# %%
# review the collections in our database
pprint(uk_food_db.establishments.find_one())
# Out:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Refreshment Kiosk',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 254719,
#  'LocalAuthorityBusinessID': 'PI/000069980',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-03-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63ddd1810df868f3faa8c63f'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/254719',
#             'rel': 'self'}],
# ...

# %%
# assign the collection to a variable
establishments = uk_food_db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query_20 = {"scores.Hygiene" : 20}

# Use count_documents to display the number of documents in the result
count_20 = establishments.count_documents(query_20)
print("Number of documents:", count_20)
# Display the first document in the results using pprint
result = establishments.find(query_20 )
pprint(result)
# Out:
# Number of documents: 41
# ...

# %%
# Convert the result to a Pandas DataFrame
results_20 = establishments.find(query_20)
result_df = pd.DataFrame(results_20)
len(result_df)
# Display the number of rows in the DataFrame
# print(result_df.shape[0])
# # Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  63ddd1850df868f3faa8e458   110681                  0
# 1  63ddd1850df868f3faa8e7d9   612039                  0
# 2  63ddd1860df868f3faa8eae3   730933                  0
# 3  63ddd1860df868f3faa8ecd1   172735                  0
# 4  63ddd1860df868f3faa8ece0   172953                  0
# 5  63ddd1870df868f3faa8f67f   512854                  0
# 6  63ddd1870df868f3faa8f8a0  1537089                  0
# 7  63ddd18b0df868f3faa90dcb   155648                  0
# 8  63ddd18c0df868f3faa9120f  1012883                  0
# 9  63ddd18d0df868f3faa91a21   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {"LocalAuthorityName" : {"$regex" : "London"},"RatingValue" : {"$gte" : "4"}}
# london_results = establishments.find(query)
# Use count_documents to display the number of documents in the result
london_count = establishments.count_documents(query)
print("Number of documents:", london_count)
# Display the first document in the results using pprint
london_first = establishments.find(query)
pprint(london_first[0])
# Out:
# Number of documents: 34
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63ddd1880df868f3faa8fe73'),
#  'geocode': {'latitude': '51.369321', 'longitude': '0.508551'},
# ...

# %%
# Convert the result to a Pandas DataFrame
london_df = pd.DataFrame(london_first)
# Display the number of rows in the DataFrame
#print(london_df[0])
# Display the first 10 rows of the DataFrame
london_df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score\
#'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'
degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000
# penang_flavours = establishments.find_one({"BusinessName": "Penang Flavours"})

# latitude = penang_flavours["geocode"]["latitude"]

# longitude = penang_flavours["geocode"]["longitude"]

# query_penang = {"geocode.latitude": {"$gte": latitude - degree_search, "$lte": latitude + degree_search},
# "geocode.longitude": {"$gte": longitude - degree_search, "$lte": longitude + degree_search},
# "RatingValue": "5"}

query_penang = {'geocode.latitude': {'$gte':latitude-degree_search, '$lte':latitude+degree_search}, 
         'geocode.longitude': {'$gte': longitude-degree_search, '$lte': longitude+degree_search},
         'RatingValue': '5'}
sort = [('score.Hygiene', 1)]
limit = 5

# Print the results
pprint(list(establishments.find(query).sort(sort).limit(limit)))
# Out:
# [{'AddressLine1': 'Leslie Ford House',
#   'AddressLine2': 'Tilbury',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': '',
#   'BusinessName': 'Coombs Catering t/a The Lock and Key',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4636.846754121153,
#   'FHRSID': 1315095,
#   'LocalAuthorityBusinessID': 'PI/000036464',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'RM18 7EH',
#   'RatingDate': '2020-12-04T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('63ddd18d0df868f3faa91ae6'),
# ...

# %%
# Convert result to Pandas DataFrame
new_query = (establishments.find(query).sort(sort).limit(limit))
results_df=pd.DataFrame(new_query)
results_df
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  63ddd18d0df868f3faa91ae6  1315095                  0
# 1  63ddd18d0df868f3faa91ae7   294474                  0
# 2  63ddd1890df868f3faa90199  1130836                  0
# 3  63ddd1880df868f3faa8fe73   621707                  0
# 4  63ddd18b0df868f3faa90ce6   293783                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000036464  Coombs Catering t/a The Lock and Key
# 1             PI/000014647              Tilbury Seafarers Centre
# 2             PI/000034075               Mv City Cruises Erasmus
# 3             PI/000025307                             Charlie's
# 4             PI/000002614             Benfleet Motor Yacht Club
#
#               BusinessType  BusinessTypeID  \
# 0  Restaurant/Cafe/Canteen               1
# 1  Restaurant/Cafe/Canteen               1
# 2  Other catering premises            7841
# 3  Other catering premises            7841
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0\
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
pipeline = [{'$match' : {'scores.Hygiene' : 0}}, {'$group' : {'_id' : 'LocalAuthorityName', 'count' : {'$sum' : 1}}},
            {'$sort' : {'count' : -1}}]
# Print the number of documents in the result
#The aggregation pipeline is correctly sent to the aggregate() method
result= list(establishments.aggregate(pipeline))
# Print the first 10 results
pprint(result[0:10])
# Out:
# [{'_id': 'LocalAuthorityName', 'count': 17304}]

# %%
# Convert the result to a Pandas DataFrame
zero_results_df = pd.DataFrame(result)
# Display the number of rows in the DataFrame
#print(zero_results_df.shape[0])
# Display the first 10 rows of the DataFrame
zero_results_df.head(10)
# Out:
#                   _id  count
# 0  LocalAuthorityName  17304
